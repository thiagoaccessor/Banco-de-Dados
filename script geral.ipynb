-- %% [markdown]
-- # [dbo].[Administração]

-- %%
USE [condominio]
GO

-- %%
/****** Object:  Table [dbo].[Administração]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Administração](
	[id_admin] [int] NOT NULL,
	[nome] [varchar](40) NOT NULL,
	[funcao] [varchar](20) NOT NULL,
	[endereco] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_admin] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agendamento_festas]

-- %%
/****** Object:  Table [dbo].[Agendamento_festas]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agendamento_festas](
	[id_agendamento] [int] NOT NULL,
	[Data_Horario] [datetime] NOT NULL,
	[id_morador] [int] NOT NULL,
	[id_salao] [int] NOT NULL,
	[id_visitante] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_agendamento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Apartamento]

-- %%
/****** Object:  Table [dbo].[Apartamento]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Apartamento](
	[id_apartamento] [int] NOT NULL,
	[Andar] [int] NOT NULL,
	[Numero] [int] NOT NULL,
	[id_bloco] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_apartamento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Blocos]

-- %%
/****** Object:  Table [dbo].[Blocos]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Blocos](
	[id_bloco] [int] NOT NULL,
	[Bloco] [varchar](2) NOT NULL,
	[id_morador] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_bloco] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Morador]

-- %%
/****** Object:  Table [dbo].[Morador]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Morador](
	[id_morador] [int] IDENTITY(1,1) NOT NULL,
	[nome] [varchar](255) NOT NULL,
	[telefone] [bigint] NOT NULL,
	[interfone] [int] NOT NULL,
	[email] [varchar](200) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_morador] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Salão]

-- %%
/****** Object:  Table [dbo].[Salão]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Salão](
	[id_salao] [int] NOT NULL,
	[Salão] [int] NOT NULL,
	[id_bloco] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_salao] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vagas]

-- %%
/****** Object:  Table [dbo].[Vagas]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vagas](
	[id_vagas] [int] NOT NULL,
	[Numero_vaga] [int] NULL,
	[id_apartamento] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_vagas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Visitante_Morador]

-- %%
/****** Object:  Table [dbo].[Visitante_Morador]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Visitante_Morador](
	[id_visitante] [int] NULL,
	[id_morador] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[visitantes]

-- %%
/****** Object:  Table [dbo].[visitantes]    Script Date: 10/02/2023 09:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[visitantes](
	[id_visitante] [int] IDENTITY(1,1) NOT NULL,
	[nome] [varchar](50) NULL,
	[telefone] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_visitante] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_MoradorAgenda]

-- %%
ALTER TABLE [dbo].[Agendamento_festas]  WITH CHECK ADD  CONSTRAINT [FK_MoradorAgenda] FOREIGN KEY([id_morador])
REFERENCES [dbo].[Morador] ([id_morador])
GO
ALTER TABLE [dbo].[Agendamento_festas] CHECK CONSTRAINT [FK_MoradorAgenda]
GO

-- %% [markdown]
-- # [FK_SalaoAgenda]

-- %%
ALTER TABLE [dbo].[Agendamento_festas]  WITH CHECK ADD  CONSTRAINT [FK_SalaoAgenda] FOREIGN KEY([id_salao])
REFERENCES [dbo].[Salão] ([id_salao])
GO
ALTER TABLE [dbo].[Agendamento_festas] CHECK CONSTRAINT [FK_SalaoAgenda]
GO

-- %% [markdown]
-- # [FK_VisitanteAgenda]

-- %%
ALTER TABLE [dbo].[Agendamento_festas]  WITH CHECK ADD  CONSTRAINT [FK_VisitanteAgenda] FOREIGN KEY([id_visitante])
REFERENCES [dbo].[visitantes] ([id_visitante])
GO
ALTER TABLE [dbo].[Agendamento_festas] CHECK CONSTRAINT [FK_VisitanteAgenda]
GO

-- %% [markdown]
-- # [FK_BlocoApt]

-- %%
ALTER TABLE [dbo].[Apartamento]  WITH CHECK ADD  CONSTRAINT [FK_BlocoApt] FOREIGN KEY([id_bloco])
REFERENCES [dbo].[Blocos] ([id_bloco])
GO
ALTER TABLE [dbo].[Apartamento] CHECK CONSTRAINT [FK_BlocoApt]
GO

-- %% [markdown]
-- # [FK_BlocoMorador]

-- %%
ALTER TABLE [dbo].[Blocos]  WITH CHECK ADD  CONSTRAINT [FK_BlocoMorador] FOREIGN KEY([id_morador])
REFERENCES [dbo].[Morador] ([id_morador])
GO
ALTER TABLE [dbo].[Blocos] CHECK CONSTRAINT [FK_BlocoMorador]
GO

-- %% [markdown]
-- # [FK_blocosalao]

-- %%
ALTER TABLE [dbo].[Salão]  WITH CHECK ADD  CONSTRAINT [FK_blocosalao] FOREIGN KEY([id_bloco])
REFERENCES [dbo].[Blocos] ([id_bloco])
GO
ALTER TABLE [dbo].[Salão] CHECK CONSTRAINT [FK_blocosalao]
GO

-- %% [markdown]
-- # [FK_AptoVagas]

-- %%
ALTER TABLE [dbo].[Vagas]  WITH CHECK ADD  CONSTRAINT [FK_AptoVagas] FOREIGN KEY([id_apartamento])
REFERENCES [dbo].[Apartamento] ([id_apartamento])
GO
ALTER TABLE [dbo].[Vagas] CHECK CONSTRAINT [FK_AptoVagas]
GO

-- %% [markdown]
-- # [fk_morador]

-- %%
ALTER TABLE [dbo].[Visitante_Morador]  WITH CHECK ADD  CONSTRAINT [fk_morador] FOREIGN KEY([id_morador])
REFERENCES [dbo].[Morador] ([id_morador])
GO
ALTER TABLE [dbo].[Visitante_Morador] CHECK CONSTRAINT [fk_morador]
GO

-- %% [markdown]
-- # [fk_visitante]

-- %%
ALTER TABLE [dbo].[Visitante_Morador]  WITH CHECK ADD  CONSTRAINT [fk_visitante] FOREIGN KEY([id_visitante])
REFERENCES [dbo].[visitantes] ([id_visitante])
GO
ALTER TABLE [dbo].[Visitante_Morador] CHECK CONSTRAINT [fk_visitante]
GO
